# %% [markdown]
# <div align="center">
#     <img src="https://www.unad.edu.co/images/footer/logo-unad-acreditacion-min.png" alt="Logo UNAD" width="780" height="140"/>
# </div>

# %% [markdown]
# <div align="center">
#     <h2>203008072 - Métodos Estadísticos en la Ciencia de Datos y Analítica</h2>
#     <h3>Tarea 1 - Análisis exploratorio e inferencial</h3>
#     <p><strong>Presentado por:</strong> Camilo Andrés Losada Ule</p>
#     <p><strong>Grupo:</strong> 203008072A_2032</p>
#     <p><strong>Código:</strong> 1084898248</p>
#     <p><strong>Tutor(a):</strong> Andrés Felipe Solís</p>
#     <p><strong>Fecha:</strong> Mayo 12 de 2025</p>
#     <p><strong>UNIVERSIDAD NACIONAL ABIERTA Y A DISTANCIA - UNAD</strong></p>
# </div>

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install scikit-learn
# Out:
# Requirement already satisfied: pandas in c:\users\user\anaconda3\anaconda 29 12\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\user\anaconda3\anaconda 29 12\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\anaconda 29 12\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\anaconda 29 12\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\anaconda 29 12\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\anaconda 29 12\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\anaconda 29 12\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\anaconda 29 12\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\anaconda 29 12\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\anaconda 29 12\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\anaconda3\anaconda 29 12\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\user\anaconda3\anaconda 29 12\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\anaconda 29 12\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\user\anaconda3\anaconda 29 12\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\anaconda 29 12\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\anaconda 29 12\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\anaconda 29 12\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: scikit-learn in c:\users\user\anaconda3\anaconda 29 12\lib\site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\user\anaconda3\anaconda 29 12\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\user\anaconda3\anaconda 29 12\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\user\anaconda3\anaconda 29 12\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\user\anaconda3\anaconda 29 12\lib\site-packages (from scikit-learn) (3.5.0)

# %%
import pandas as pd
df = pd.read_csv("C:/Users/USER/OneDrive - INSTITUTO TECNOLOGICO METROPOLITANO - ITM/Documents/CAMILO ANDRES LOSADA/METODOS ESTADISTICOS II SEMESTRE/dynamic_pricing.csv")
df.head()
# Out:
#    Number_of_Riders  Number_of_Drivers Location_Category  \
# 0                90                 45             Urban
# 1                58                 39          Suburban
# 2                42                 31             Rural
# 3                89                 28             Rural
# 4                78                 22             Rural
#
#   Customer_Loyalty_Status  Number_of_Past_Rides  Average_Ratings  \
# 0                  Silver                    13             4.47
# 1                  Silver                    72             4.06
# 2                  Silver                     0             3.99
# 3                 Regular                    67             4.31
# 4                 Regular                    74             3.77
#
#   Time_of_Booking Vehicle_Type  Expected_Ride_Duration  \
# 0           Night      Premium                      90
# 1         Evening      Economy                      43
# 2       Afternoon      Premium                      76
# 3       Afternoon      Premium                     134
# 4       Afternoon      Economy                     149
#
#    Historical_Cost_of_Ride
# 0               284.257273
# 1               173.874753
# 2               329.795469
# 3               470.201232
# 4               579.681422

# %% [markdown]
# # 1. ANÁLISIS UNIDIMENSIONAL.

# %% [markdown]
# ### 1. Diccionario de datos

# %%
diccionario_datos = pd.DataFrame({
    "Nombre de la variable": [
        "Number_of_Riders",
        "Number_of_Drivers",
        "Location_Category",
        "Customer_Loyalty_Status",
        "Number_of_Past_Rides",
        "Average_Ratings",
        "Time_of_Booking",
        "Vehicle_Type",
        "Expected_Ride_Duration",
        "Historical_Cost_of_Ride"
    ],
    "Descripción de la variable": [
        "Número de pasajeros en el viaje",
        "Número de conductores disponibles para el viaje",
        "Categoría de la ubicación del usuario (urbana, rural, etc.)",
        "Estado de lealtad del cliente (nuevo, recurrente, fidelizado)",
        "Número de viajes previos realizados por el cliente",
        "Promedio de las calificaciones dadas al servicio",
        "Hora de la reserva del viaje",
        "Tipo de vehículo utilizado en el viaje",
        "Duración estimada del viaje",
        "Costo histórico del viaje"
    ],
    "Clasificación": [
        "Numérica",
        "Numérica",
        "Categórica",
        "Categórica",
        "Numérica",
        "Numérica",
        "Categórica",
        "Categórica",
        "Numérica",
        "Numérica"
    ]
})

# Mostrar diccionario de datos
diccionario_datos
# Out:
#      Nombre de la variable                         Descripción de la variable  \
# 0         Number_of_Riders                    Número de pasajeros en el viaje
# 1        Number_of_Drivers    Número de conductores disponibles para el viaje
# 2        Location_Category  Categoría de la ubicación del usuario (urbana,...
# 3  Customer_Loyalty_Status  Estado de lealtad del cliente (nuevo, recurren...
# 4     Number_of_Past_Rides  Número de viajes previos realizados por el cli...
# 5          Average_Ratings   Promedio de las calificaciones dadas al servicio
# 6          Time_of_Booking                       Hora de la reserva del viaje
# 7             Vehicle_Type             Tipo de vehículo utilizado en el viaje
# 8   Expected_Ride_Duration                        Duración estimada del viaje
# 9  Historical_Cost_of_Ride                          Costo histórico del viaje
#
#   Clasificación
# 0      Numérica
# 1      Numérica
# 2    Categórica
# 3    Categórica
# 4      Numérica
# 5      Numérica
# 6    Categórica
# 7    Categórica
# 8      Numérica
# 9      Numérica

# %% [markdown]
# ### 2. Tablas de Distribución de Frecuencias y Gráficas de Variables Categóricas

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Seleccionamos las variables categóricas
variables_categoricas = ['Location_Category', 'Customer_Loyalty_Status', 'Vehicle_Type', 'Time_of_Booking']  # Variables categóricas

# Mostrar tablas de frecuencia y gráficas
for var in variables_categoricas:
    print(f"\nDistribución de frecuencias para {var}:")
    print(df[var].value_counts())
    
    # Gráfico de barras
    plt.figure(figsize=(6, 4))
    sns.countplot(data=df, x=var, order=df[var].value_counts().index, palette="Set2")
    plt.title(f"Distribución de {var}")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
# Out:
# Distribución de frecuencias para Location_Category:
# Location_Category
# Urban       346
# Rural       332
# Suburban    322
# Name: count, dtype: int64
# C:\Users\USER\AppData\Local\Temp\ipykernel_15720\2269545960.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=var, order=df[var].value_counts().index, palette="Set2")
# Distribución de frecuencias para Customer_Loyalty_Status:
# Customer_Loyalty_Status
# Silver     367
# Regular    320
# Gold       313
# Name: count, dtype: int64
# C:\Users\USER\AppData\Local\Temp\ipykernel_15720\2269545960.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=var, order=df[var].value_counts().index, palette="Set2")
# Distribución de frecuencias para Vehicle_Type:
# Vehicle_Type
# Premium    522
# Economy    478
# Name: count, dtype: int64
# C:\Users\USER\AppData\Local\Temp\ipykernel_15720\2269545960.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=var, order=df[var].value_counts().index, palette="Set2")
# Distribución de frecuencias para Time_of_Booking:
# Time_of_Booking
# Night        276
# Afternoon    247
# Morning      246
# Evening      231
# Name: count, dtype: int64
# C:\Users\USER\AppData\Local\Temp\ipykernel_15720\2269545960.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=var, order=df[var].value_counts().index, palette="Set2")

# %% [markdown]
# ### 3. Medidas de Resumen

# %%
# Variables numéricas
variables_numericas = ['Number_of_Riders', 'Number_of_Drivers', 'Number_of_Past_Rides', 'Average_Ratings', 
                       'Expected_Ride_Duration', 'Historical_Cost_of_Ride']  # Variables numéricas

# Medidas de resumen
resumen = df[variables_numericas].describe().T
resumen[['mean', 'std', 'min', '25%', '50%', '75%', 'max']]
# Out:
#                                mean         std        min         25%  \
# Number_of_Riders          60.372000   23.701506  20.000000   40.000000
# Number_of_Drivers         27.076000   19.068346   5.000000   11.000000
# Number_of_Past_Rides      50.031000   29.313774   0.000000   25.000000
# Average_Ratings            4.257220    0.435781   3.500000    3.870000
# Expected_Ride_Duration    99.588000   49.165450  10.000000   59.750000
# Historical_Cost_of_Ride  372.502623  187.158756  25.993449  221.365202
#
#                                 50%         75%         max
# Number_of_Riders          60.000000   81.000000  100.000000
# Number_of_Drivers         22.000000   38.000000   89.000000
# Number_of_Past_Rides      51.000000   75.000000  100.000000
# Average_Ratings            4.270000    4.632500    5.000000
# Expected_Ride_Duration   102.000000  143.000000  180.000000
# Historical_Cost_of_Ride  362.019426  510.497504  836.116419

# %% [markdown]
# ### 4. Análisis de la Distribución de Variables mediante Boxplot o Violin Plot

# %%
# Boxplots para todas las variables numéricas
plt.figure(figsize=(12, 6))
for i, var in enumerate(variables_numericas):
    plt.subplot(1, len(variables_numericas), i+1)
    sns.boxplot(y=df[var], color='lightblue')
    plt.title(var)
plt.tight_layout()
plt.show()

# %%
# Violin Plots para todas las variables numéricas
plt.figure(figsize=(12, 6))
for i, var in enumerate(variables_numericas):
    plt.subplot(1, len(variables_numericas), i+1)
    sns.violinplot(y=df[var], color='lightblue')
    plt.title(var)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. ANALISIS BIDIMENSIONAL E INFERENCIAL

# %% [markdown]
# ### 5. Correlación dos a dos (Scatterplots + Pearson)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Variables numéricas de interés
pares = [
    ('Number_of_Riders', 'Historical_Cost_of_Ride'),
    ('Average_Ratings', 'Historical_Cost_of_Ride'),
    ('Expected_Ride_Duration', 'Historical_Cost_of_Ride')
]

# Generar los scatterplots
for x_var, y_var in pares:
    sns.lmplot(data=df, x=x_var, y=y_var, height=5, aspect=1.2, line_kws={'color': 'red'})
    plt.title(f'{x_var} vs {y_var}')
    plt.tight_layout()
    plt.show()

# %%
from scipy.stats import pearsonr

for x_var, y_var in pares:
    r, p = pearsonr(df[x_var], df[y_var])
    print(f"\nCorrelación Pearson entre {x_var} y {y_var}:")
    print(f"Coeficiente r = {r:.4f}")
    print(f"Valor-p = {p:.4f}")

    if abs(r) >= 0.7:
        nivel = "fuerte"
    elif abs(r) >= 0.4:
        nivel = "moderada"
    elif abs(r) >= 0.2:
        nivel = "débil"
    else:
        nivel = "muy débil o nula"

    print(f"Interpretación: Correlación {nivel}, {'significativa' if p < 0.05 else 'no significativa'}")
# Out:
# Correlación Pearson entre Number_of_Riders y Historical_Cost_of_Ride:
# Coeficiente r = 0.0058
# Valor-p = 0.8540
# Interpretación: Correlación muy débil o nula, no significativa
#
# Correlación Pearson entre Average_Ratings y Historical_Cost_of_Ride:
# Coeficiente r = -0.0011
# Valor-p = 0.9732
# Interpretación: Correlación muy débil o nula, no significativa
#
# Correlación Pearson entre Expected_Ride_Duration y Historical_Cost_of_Ride:
# Coeficiente r = 0.9275
# Valor-p = 0.0000
# Interpretación: Correlación fuerte, significativa

# %% [markdown]
# ### 6. Asociación entre variables categóricas (Chi-cuadrado)

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Pares categóricos a evaluar
categoricos = [
    ('Customer_Loyalty_Status', 'Time_of_Booking'),
    ('Customer_Loyalty_Status', 'Vehicle_Type'),
    ('Customer_Loyalty_Status', 'Location_Category')
]

# Analizar cada par con tabla de contingencia y prueba chi-cuadrado
for var1, var2 in categoricos:
    print(f"\nTabla de contingencia: {var1} vs {var2}")
    tabla = pd.crosstab(df[var1], df[var2])
    print(tabla)
    
    chi2, p, dof, expected = chi2_contingency(tabla)
    print(f"\nResultado Chi-Cuadrado: χ² = {chi2:.4f}, p = {p:.4f}, gl = {dof}")
    
    if p < 0.05:
        print("➡ Existe una asociación estadísticamente significativa entre las variables.")
    else:
        print("➡ No se encuentra asociación significativa entre las variables.")
# Out:
# Tabla de contingencia: Customer_Loyalty_Status vs Time_of_Booking
# Time_of_Booking          Afternoon  Evening  Morning  Night
# Customer_Loyalty_Status
# Gold                            68       76       79     90
# Regular                         89       74       79     78
# Silver                          90       81       88    108
#
# Resultado Chi-Cuadrado: χ² = 4.6504, p = 0.5894, gl = 6
# ➡ No se encuentra asociación significativa entre las variables.
#
# Tabla de contingencia: Customer_Loyalty_Status vs Vehicle_Type
# Vehicle_Type             Economy  Premium
# Customer_Loyalty_Status
# Gold                         153      160
# Regular                      144      176
# Silver                       181      186
#
# Resultado Chi-Cuadrado: χ² = 1.4916, p = 0.4744, gl = 2
# ➡ No se encuentra asociación significativa entre las variables.
#
# Tabla de contingencia: Customer_Loyalty_Status vs Location_Category
# Location_Category        Rural  Suburban  Urban
# Customer_Loyalty_Status
# Gold                       112        92    109
# Regular                    103       107    110
# Silver                     117       123    127
#
# Resultado Chi-Cuadrado: χ² = 2.0447, p = 0.7275, gl = 4
# ➡ No se encuentra asociación significativa entre las variables.

# %% [markdown]
# ### 7. Comparación de medias por fidelidad del cliente (ANOVA + Post Hoc)

# %%
# Variables a analizar
variables_analisis = ['Number_of_Riders', 'Average_Ratings', 'Expected_Ride_Duration']

for var in variables_analisis:
    plt.figure(figsize=(6, 4))
    sns.boxplot(data=df, x='Customer_Loyalty_Status', y=var, palette="Pastel1")
    plt.title(f'{var} según Customer_Loyalty_Status')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_15720\1038234955.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Customer_Loyalty_Status', y=var, palette="Pastel1")
# C:\Users\USER\AppData\Local\Temp\ipykernel_15720\1038234955.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Customer_Loyalty_Status', y=var, palette="Pastel1")
# C:\Users\USER\AppData\Local\Temp\ipykernel_15720\1038234955.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Customer_Loyalty_Status', y=var, palette="Pastel1")

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.multicomp import pairwise_tukeyhsd

for var in variables_analisis:
    print(f"\nANOVA para {var} según Customer_Loyalty_Status")
    
    modelo = ols(f'{var} ~ C(Customer_Loyalty_Status)', data=df).fit()
    anova_tabla = sm.stats.anova_lm(modelo, typ=2)
    print(anova_tabla)
    
    p_valor = anova_tabla['PR(>F)'][0]
    
    if p_valor < 0.05:
        print("➡ Diferencias significativas detectadas. Ejecutando prueba Post Hoc (Tukey)...")
        posthoc = pairwise_tukeyhsd(df[var], df['Customer_Loyalty_Status'])
        print(posthoc)
    else:
        print("➡ No se detectan diferencias significativas entre grupos.")
# Out:
# ANOVA para Number_of_Riders según Customer_Loyalty_Status
#                                    sum_sq     df         F    PR(>F)
# C(Customer_Loyalty_Status)    2670.529942    2.0  2.383509  0.092752
# Residual                    558529.086058  997.0       NaN       NaN
# ➡ No se detectan diferencias significativas entre grupos.
#
# ANOVA para Average_Ratings según Customer_Loyalty_Status
#                                 sum_sq     df         F    PR(>F)
# C(Customer_Loyalty_Status)    0.876696    2.0  2.314323  0.099364
# Residual                    188.838375  997.0       NaN       NaN
# ➡ No se detectan diferencias significativas entre grupos.
#
# ANOVA para Expected_Ride_Duration según Customer_Loyalty_Status
#                                   sum_sq     df         F    PR(>F)
# C(Customer_Loyalty_Status)  4.004857e+03    2.0  0.828109  0.437175
# Residual                    2.410819e+06  997.0       NaN       NaN
# ➡ No se detectan diferencias significativas entre grupos.
# C:\Users\USER\AppData\Local\Temp\ipykernel_15720\2551683148.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_valor = anova_tabla['PR(>F)'][0]
# C:\Users\USER\AppData\Local\Temp\ipykernel_15720\2551683148.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_valor = anova_tabla['PR(>F)'][0]
# C:\Users\USER\AppData\Local\Temp\ipykernel_15720\2551683148.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_valor = anova_tabla['PR(>F)'][0]
